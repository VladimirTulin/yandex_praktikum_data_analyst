# %% [markdown]
# ### Задача:
#
# Проанализировать клиентов регионального банка и выделить портрет клиентов, которые склонны уходить из банка.
#
# ### Заказчик:
#
# Менеджер продукта, который разрабатывает меры по удержанию клиентов.

# %% [markdown]
# _____

# %% [markdown]
# #### Анализ оттока в региональном банке
#
# 1. #### Загрузка, первичный осмотр и предобработка данных
#  - изучение пропусков
#  - приведение типов данных
#  - поиск дубликатов
#  - сделать вывод
# 2. #### Исследовательский анализ данных
#  - изучить средние значения признаков клиентов
#  - изучить распределения признаков
#  - сделать вывод
# 3. #### Описание портрета клиента склонного уходить
#  - Использовать средние значения характеристик
# 4. #### Проверка статистических гипотез
#  - Проверить основную гипотезу о различиях дохода между теми клиентами, которые ушли (отток) и теми, которые остались
#     - изучить распределения признака, визуализировать
#     - провести корреляционный анализ, визуализировать
#     - проверить гипотезу
#  - проверить дополнительную гипотезу о различиях количества используемых продуктов между теми клиентами, которые ушли (отток) и теми, которые остались
#     - изучить распределения признака, визуализировать
#     - провести корреляционный анализ, визуализировать
#     - проверить гипотезу
#  - сделать вывод
# 5. #### Выводы
# - Общие вывод__ы__ о проделанной работе
# - Дать рекомендации по удержанию клиентов
# 6. #### Создать дашборд
#  - Набор №2
#     1. Построить диаграмму, отображающую распределение заработной платы клиентов.
#     2. Добавить индикатор, отображающий процент клиентов, имеющих кредитную карту.
#     3. Добавить фильтр дашборда, позволяющий выбрать ушёл клиент или нет.
# 7. #### Составить презентацию

# %% [markdown]
# ______
